# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Load data

# %%
country_sample = pd.read_csv('../data/external/country_sample.csv')

# %%
country_sample.columns
# Out:
# Index(['scenario', 'country', 'region', 'sector', 'wregion', 'year', 'urt',
#        'activity', 'technology', 'perc'],
#       dtype='object')

# %%
country_sample['' \
''].unique()
# Out:
# array([0.00000000e+00, 8.78126395e+01, 9.06249801e+00, 3.12486251e+00,
#        8.62871409e+01, 1.01968559e+01, 3.51600326e+00, 2.40339376e+01,
#        6.37787019e+01, 9.06249801e+00, 3.12486251e+00, 2.36164153e+01,
#        6.26707256e+01, 1.01968558e+01, 3.51600326e+00, 1.44000000e+01,
#        8.56000000e+01, 1.84000000e+01, 8.16000000e+01, 1.28000000e+01,
#        8.72000000e+01, 3.39000000e+01, 6.61000000e+01, 1.48986864e+00,
#        3.45474290e-02, 1.55823665e-01, 9.83197603e+01, 1.00000000e+02,
#        1.51000000e+01, 8.49000000e+01, 2.00000000e+01, 8.00000000e+01,
#        6.64000000e+01, 3.36000000e+01, 6.84000000e+01, 3.16000000e+01,
#        4.00000000e+01, 6.00000000e+01, 8.19000000e+01, 1.81000000e+01,
#        7.04000000e+01, 2.96000000e+01, 3.19500000e+01, 6.80500000e+01,
#        2.69500000e+01, 7.30500000e+01, 1.75000000e+01, 8.25000000e+01,
#        5.92000000e+01, 4.08000000e+01, 5.67000000e+01, 4.33000000e+01,
# ...

# %%
scen = 'reference'
